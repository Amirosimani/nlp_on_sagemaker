# %% [markdown]
# Upgrade to the latest `sagemaker` version.

# %%
# !pip install "sagemaker" -qU

# %%
import boto3
import numpy as np
import pandas as pd

import sagemaker
from sagemaker import TrainingJobAnalytics
from sagemaker.huggingface import HuggingFace, HuggingFaceModel

# %%
# permissions
sess = sagemaker.Session()
role = sagemaker.get_execution_role()
s3_client = boto3.client('s3')

bucket = sess.default_bucket()
prefix = "huggingface_classifier"
sess = sagemaker.Session(default_bucket=bucket)

print(f"sagemaker role arn: {role}")
print(f"sagemaker bucket: {sess.default_bucket()}")
print(f"sagemaker session region: {sess.boto_region_name}")
# Out:
# sagemaker role arn: arn:aws:iam::367158743199:role/service-role/AmazonSageMaker-ExecutionRole-20210413T121296
# sagemaker bucket: sagemaker-us-east-1-367158743199
# sagemaker session region: us-east-1

# %% [markdown]
# # Downloading the Dataset

# %%
df = pd.read_csv('./data/Womens Clothing E-Commerce Reviews.csv')
df = df[['Review Text',	'Rating']]
df.columns = ['text', 'label']
df['label'] = df['label'] - 1

df = df.dropna()

train, validate, test = \
              np.split(df.sample(frac=1, random_state=42), 
                       [int(.6*len(df)), int(.8*len(df))])

train.shape, validate.shape, test.shape
# Out:
# ((13584, 2), (4528, 2), (4529, 2))

# %%
train.to_csv('./data/train.csv', index=False)
validate.to_csv('./data/validate.csv', index=False)
test.to_csv('./data/test.csv', index=False)

# %%
s3_client.upload_file('./data/train.csv', bucket,
                      f'{prefix}/data/train.csv')
s3_client.upload_file('./data/validate.csv', bucket,
                      f'{prefix}/data/validate.csv')
s3_client.upload_file('./data/test.csv', bucket,
                      f'{prefix}/data/test.csv')

# %% [markdown]
# ## Prepare a HuggingFace Transformers fine-tuning script.

# %%
# !mkdir ./src
# Out:
# mkdir: cannot create directory ‘./src’: File exists

# %%
# %%writefile src/train_2.py

import os
import sys
import logging
import argparse
from datasets import load_dataset
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from transformers.trainer_utils import get_last_checkpoint
from transformers import AutoModelForSequenceClassification, Trainer, TrainingArguments, AutoTokenizer


# Set up logging
logger = logging.getLogger(__name__)

logging.basicConfig(
    level=logging.getLevelName("INFO"),
    handlers=[logging.StreamHandler(sys.stdout)],
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
)

if __name__ == "__main__":

    logger.info(sys.argv)

    parser = argparse.ArgumentParser()

    # hyperparameters sent by the client are passed as command-line arguments to the script.
    parser.add_argument("--epochs", type=int, default=3)
    parser.add_argument("--train-batch-size", type=int, default=32)
    parser.add_argument("--eval-batch-size", type=int, default=64)
    parser.add_argument("--warmup_steps", type=int, default=500)
    parser.add_argument("--model_name", type=str)
    parser.add_argument("--learning_rate", type=str, default=5e-5)
    parser.add_argument("--output_dir", type=str)

    # Data, model, and output directories
    parser.add_argument("--output-data-dir", type=str, default=os.environ["SM_OUTPUT_DATA_DIR"])
    parser.add_argument("--model-dir", type=str, default=os.environ["SM_MODEL_DIR"])
    parser.add_argument("--n_gpus", type=str, default=os.environ["SM_NUM_GPUS"])
    parser.add_argument("--training_dir", type=str, default=os.environ["SM_CHANNEL_TRAIN"])
    parser.add_argument("--test_dir", type=str, default=os.environ["SM_CHANNEL_TEST"])

    args, _ = parser.parse_known_args()
    
    # Set up logging
    logger = logging.getLogger(__name__)

    logging.basicConfig(
        level=logging.getLevelName("INFO"),
        handlers=[logging.StreamHandler(sys.stdout)],
        format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    )
   
    # download tokenizer
    tokenizer = AutoTokenizer.from_pretrained(args.model_name)
    
    # Load dataset
    train_file = f"{args.training_dir}/train.csv"
    validate_file = f"{args.test_dir}/validate.csv"
    dataset = load_dataset('csv', data_files={'train': train_file,
                                             'test': validate_file})
    
    train_dataset = dataset['train']
    test_dataset = dataset['test']
    logger.info(f" loaded train_dataset length is: {len(train_dataset)}")
    logger.info(f" loaded test_dataset length is: {len(test_dataset)}")


    # tokenizer helper function
    def tokenize(batch):
        return tokenizer(batch['text'], padding='max_length', truncation=True)

    # tokenize dataset
    train_dataset = train_dataset.map(tokenize, batched=True)
    test_dataset = test_dataset.map(tokenize, batched=True)
    

    # set format for pytorch
    train_dataset =  train_dataset.rename_column("label", "labels")
    train_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'labels'])
    test_dataset = test_dataset.rename_column("label", "labels")
    test_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'labels'])

    logger.info(f" loaded train_dataset length is: {len(train_dataset)}")
    logger.info(f" loaded test_dataset length is: {len(test_dataset)}")

    # compute metrics function for binary classification
    def compute_metrics(pred):
        labels = pred.label_ids
        preds = pred.predictions.argmax(-1)
        precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average="weighted")
        acc = accuracy_score(labels, preds)
        return {"accuracy": acc, "f1": f1, "precision": precision, "recall": recall}

    # download model from model hub
    model = AutoModelForSequenceClassification.from_pretrained(args.model_name, num_labels=5)

    # define training args
    training_args = TrainingArguments(
        output_dir=args.output_dir,
        num_train_epochs=args.epochs,
        per_device_train_batch_size=args.train_batch_size,
        per_device_eval_batch_size=args.eval_batch_size,
        warmup_steps=args.warmup_steps,
        evaluation_strategy="epoch",
        logging_dir=f"{args.output_data_dir}/logs",
        learning_rate=float(args.learning_rate),
    )

    # create Trainer instance
    trainer = Trainer(
        model=model,
        args=training_args,
        compute_metrics=compute_metrics,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
    )

    # train model
    if get_last_checkpoint(args.output_dir) is not None:
        logger.info("***** continue training *****")
        trainer.train(resume_from_checkpoint=args.output_dir)
    else:
        trainer.train()
    # evaluate model
    eval_result = trainer.evaluate(eval_dataset=test_dataset)

    # writes eval result to file which can be accessed later in s3 ouput
    with open(os.path.join(args.output_data_dir, "eval_results.txt"), "w") as writer:
        print(f"***** Eval results *****")
        for key, value in sorted(eval_result.items()):
            writer.write(f"{key} = {value}\n")

    # Saves the model to s3
    trainer.save_model(args.model_dir)
# Out:
# Overwriting src/train_2.py

# %% [markdown]
# ## Create an HuggingFace Estimator

# %%
# hyperparameters, which are passed into the training job
hyperparameters={'epochs': 1,
                 'train_batch_size': 32,
                 'model_name':'distilbert-base-uncased',
                 'output_dir':'/opt/ml/checkpoints'
                 }



metric_definitions=[
    {'Name': 'loss', 'Regex': "'loss': ([0-9]+(.|e\-)[0-9]+),?"},
    {'Name': 'learning_rate', 'Regex': "'learning_rate': ([0-9]+(.|e\-)[0-9]+),?"},
    {'Name': 'eval_loss', 'Regex': "'eval_loss': ([0-9]+(.|e\-)[0-9]+),?"},
    {'Name': 'eval_accuracy', 'Regex': "'eval_accuracy': ([0-9]+(.|e\-)[0-9]+),?"},
    {'Name': 'eval_f1', 'Regex': "'eval_f1': ([0-9]+(.|e\-)[0-9]+),?"},
    {'Name': 'eval_precision', 'Regex': "'eval_precision': ([0-9]+(.|e\-)[0-9]+),?"},
    {'Name': 'eval_recall', 'Regex': "'eval_recall': ([0-9]+(.|e\-)[0-9]+),?"},
    {'Name': 'eval_runtime', 'Regex': "'eval_runtime': ([0-9]+(.|e\-)[0-9]+),?"},
    {'Name': 'eval_samples_per_second', 'Regex': "'eval_samples_per_second': ([0-9]+(.|e\-)[0-9]+),?"},
    {'Name': 'epoch', 'Regex': "'epoch': ([0-9]+(.|e\-)[0-9]+),?"}]

# %%
# s3 uri where our checkpoints will be uploaded during training
job_name = "using-spot"
checkpoint_s3_uri = f's3://{bucket}/{job_name}/checkpoints'

# create the Estimator
huggingface_estimator = HuggingFace(entry_point='train_2.py',
                            source_dir='./src',
                            instance_type='ml.p3.2xlarge',
                            size=5,
                            instance_count=1,
                            base_job_name=job_name,
                            checkpoint_s3_uri=checkpoint_s3_uri,
#                             use_spot_instances=True,
#                             max_wait=3600, # This should be equal to or greater than max_run in seconds'
#                             max_run=1000, # expected max run in seconds
                            role=role,
                            transformers_version='4.6',
                            pytorch_version='1.7',
                            py_version='py36',
                            hyperparameters = hyperparameters,
#                             metric_definitions=metric_definitions
                            )

# %% [markdown]
# # Excute the fine-tuning Job

# %%
data = {'train': f"s3://{bucket}/{prefix}/data/train.csv",
        'test': f"s3://{bucket}/{prefix}/data/validate.csv"
       }

huggingface_estimator.fit(data)
# Out:
# 2021-07-16 21:02:47 Starting - Starting the training job...
# 2021-07-16 21:03:11 Starting - Launching requested ML instancesProfilerReport-1626469367: InProgress
# ......
# 2021-07-16 21:04:11 Starting - Preparing the instances for training.........
# 2021-07-16 21:05:36 Downloading - Downloading input data
# 2021-07-16 21:05:36 Training - Downloading the training image..................
# 2021-07-16 21:08:44 Training - Training image download completed. Training in progress..bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-07-16 21:08:44,449 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2021-07-16 21:08:44,473 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2021-07-16 21:08:47,494 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2021-07-16 21:08:47,893 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "train_batch_size": 32,
#         "model_name": "distilbert-base-uncased",
#         "output_dir": "/opt/ml/checkpoints",
#         "epochs": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "using-spot-2021-07-16-21-02-47-162",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-367158743199/using-spot-2021-07-16-21-02-47-162/source/sourcedir.tar.gz",
#     "module_name": "train_2",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_2.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":1,"model_name":"distilbert-base-uncased","output_dir":"/opt/ml/checkpoints","train_batch_size":32}
# SM_USER_ENTRY_POINT=train_2.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train_2
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-367158743199/using-spot-2021-07-16-21-02-47-162/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":1,"model_name":"distilbert-base-uncased","output_dir":"/opt/ml/checkpoints","train_batch_size":32},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"using-spot-2021-07-16-21-02-47-162","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-367158743199/using-spot-2021-07-16-21-02-47-162/source/sourcedir.tar.gz","module_name":"train_2","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_2.py"}
# SM_USER_ARGS=["--epochs","1","--model_name","distilbert-base-uncased","--output_dir","/opt/ml/checkpoints","--train_batch_size","32"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_TRAIN_BATCH_SIZE=32
# SM_HP_MODEL_NAME=distilbert-base-uncased
# SM_HP_OUTPUT_DIR=/opt/ml/checkpoints
# SM_HP_EPOCHS=1
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python3.6 train_2.py --epochs 1 --model_name distilbert-base-uncased --output_dir /opt/ml/checkpoints --train_batch_size 32
#
#
# 2021-07-16 21:08:52,308 - __main__ - INFO - ['train_2.py', '--epochs', '1', '--model_name', 'distilbert-base-uncased', '--output_dir', '/opt/ml/checkpoints', '--train_batch_size', '32']
# 2021-07-16 21:08:52,494 - filelock - INFO - Lock 140204413744688 acquired on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2021-07-16 21:08:52,534 - filelock - INFO - Lock 140204413744688 released on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2021-07-16 21:08:52,559 - filelock - INFO - Lock 140204413685432 acquired on /root/.cache/huggingface/transformers/0e1bbfda7f63a99bb52e3915dcf10c3c92122b827d92eb2d34ce94ee79ba486c.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# 2021-07-16 21:08:52,590 - filelock - INFO - Lock 140204413685432 released on /root/.cache/huggingface/transformers/0e1bbfda7f63a99bb52e3915dcf10c3c92122b827d92eb2d34ce94ee79ba486c.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99.lock
# 2021-07-16 21:08:52,613 - filelock - INFO - Lock 140204413685152 acquired on /root/.cache/huggingface/transformers/75abb59d7a06f4f640158a9bfcde005264e59e8d566781ab1415b139d2e4c603.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# 2021-07-16 21:08:52,648 - filelock - INFO - Lock 140204413685152 released on /root/.cache/huggingface/transformers/75abb59d7a06f4f640158a9bfcde005264e59e8d566781ab1415b139d2e4c603.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4.lock
# 2021-07-16 21:08:52,719 - filelock - INFO - Lock 140204413684424 acquired on /root/.cache/huggingface/transformers/8c8624b8ac8aa99c60c912161f8332de003484428c47906d7ff7eb7f73eecdbb.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79.lock
# 2021-07-16 21:08:52,741 - filelock - INFO - Lock 140204413684424 released on /root/.cache/huggingface/transformers/8c8624b8ac8aa99c60c912161f8332de003484428c47906d7ff7eb7f73eecdbb.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79.lock
# 2021-07-16 21:08:52,836 - datasets.builder - WARNING - Using custom data configuration default-5f7c543818c4d488
# Downloading and preparing dataset csv/default (download: Unknown size, generated: Unknown size, post-processed: Unknown size, total: Unknown size) to /root/.cache/huggingface/datasets/csv/default-5f7c543818c4d488/0.0.0/2dc6629a9ff6b5697d82c25b73731dd440507a69cbce8b425db50b751e8fcfd0...
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-5f7c543818c4d488/0.0.0/2dc6629a9ff6b5697d82c25b73731dd440507a69cbce8b425db50b751e8fcfd0. Subsequent calls will reuse this data.
# 2021-07-16 21:08:52,965 - __main__ - INFO -  loaded train_dataset length is: 13584
# 2021-07-16 21:08:52,965 - __main__ - INFO -  loaded test_dataset length is: 4528
# 2021-07-16 21:08:55,947 - __main__ - INFO -  loaded train_dataset length is: 13584
# 2021-07-16 21:08:55,947 - __main__ - INFO -  loaded test_dataset length is: 4528
# 2021-07-16 21:08:55,998 - filelock - INFO - Lock 140204406577752 acquired on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.4.sa_layer_norm.bias count_params:768
# [2021-07-16 21:09:06.477 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.4.ffn.lin1.weight count_params:2359296
# [2021-07-16 21:09:06.477 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.4.ffn.lin1.bias count_params:3072
# [2021-07-16 21:09:06.478 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.4.ffn.lin2.weight count_params:2359296
# [2021-07-16 21:09:06.478 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.4.ffn.lin2.bias count_params:768
# [2021-07-16 21:09:06.478 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.4.output_layer_norm.weight count_params:768
# [2021-07-16 21:09:06.478 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.4.output_layer_norm.bias count_params:768
# [2021-07-16 21:09:06.478 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.5.attention.q_lin.weight count_params:589824
# [2021-07-16 21:09:06.478 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.5.attention.q_lin.bias count_params:768
# [2021-07-16 21:09:06.478 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.5.attention.k_lin.weight count_params:589824
# [2021-07-16 21:09:06.478 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.5.attention.k_lin.bias count_params:768
# [2021-07-16 21:09:06.479 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.5.attention.v_lin.weight count_params:589824
# [2021-07-16 21:09:06.479 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.5.attention.v_lin.bias count_params:768
# [2021-07-16 21:09:06.479 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.5.attention.out_lin.weight count_params:589824
# [2021-07-16 21:09:06.479 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.5.attention.out_lin.bias count_params:768
# [2021-07-16 21:09:06.479 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.5.sa_layer_norm.weight count_params:768
# [2021-07-16 21:09:06.479 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.5.sa_layer_norm.bias count_params:768
# [2021-07-16 21:09:06.479 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.5.ffn.lin1.weight count_params:2359296
# [2021-07-16 21:09:06.479 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.5.ffn.lin1.bias count_params:3072
# [2021-07-16 21:09:06.480 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.5.ffn.lin2.weight count_params:2359296
# [2021-07-16 21:09:06.480 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.5.ffn.lin2.bias count_params:768
# [2021-07-16 21:09:06.480 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.5.output_layer_norm.weight count_params:768
# [2021-07-16 21:09:06.480 algo-1:25 INFO hook.py:591] name:distilbert.transformer.layer.5.output_layer_norm.bias count_params:768
# [2021-07-16 21:09:06.480 algo-1:25 INFO hook.py:591] name:pre_classifier.weight count_params:589824
# [2021-07-16 21:09:06.480 algo-1:25 INFO hook.py:591] name:pre_classifier.bias count_params:768
# [2021-07-16 21:09:06.480 algo-1:25 INFO hook.py:591] name:classifier.weight count_params:3840
# [2021-07-16 21:09:06.480 algo-1:25 INFO hook.py:591] name:classifier.bias count_params:5
# [2021-07-16 21:09:06.480 algo-1:25 INFO hook.py:593] Total Trainable Params: 66957317
# [2021-07-16 21:09:06.480 algo-1:25 INFO hook.py:425] Monitoring the collections: losses
# [2021-07-16 21:09:06.484 algo-1:25 INFO hook.py:488] Hook is writing from the hook with pid: 25
#
# {'eval_loss': 0.8120698928833008, 'eval_accuracy': 0.6568021201413428, 'eval_f1': 0.6173947028658955, 'eval_precision': 0.604021165993444, 'eval_recall': 0.6568021201413428, 'eval_runtime': 30.2133, 'eval_samples_per_second': 149.868, 'epoch': 1.0}
# {'train_runtime': 292.6651, 'train_samples_per_second': 1.452, 'epoch': 1.0}
# ***** Eval results *****
# #015Downloading:   0%|          | 0.00/442 [00:00<?, ?B/s]#015Downloading: 100%|██████████| 442/442 [00:00<00:00, 451kB/s]
# #015Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]#015Downloading: 100%|██████████| 232k/232k [00:00<00:00, 43.1MB/s]
# #015Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]#015Downloading: 100%|██████████| 466k/466k [00:00<00:00, 46.5MB/s]
# #015Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s
#015 61%|██████    | 43/71 [00:18<00:12,  2.33it/s]#015 62%|██████▏   | 44/71 [00:18<00:11,  2.34it/s]#015 63%|██████▎   | 45/71 [00:19<00:11,  2.34it/s]#015 65%|██████▍   | 46/71 [00:19<00:10,  2.35it/s]#015 66%|██████▌   | 47/71 [00:19<00:10,  2.35it/s]#015 68%|██████▊   | 48/71 [00:20<00:09,  2.34it/s]#015 69%|██████▉   | 49/71 [00:20<00:09,  2.34it/s]#015 70%|███████   | 50/71 [00:21<00:08,  2.35it/s]#015 72%|███████▏  | 51/71 [00:21<00:08,  2.32it/s]#015 73%|███████▎  | 52/71 [00:22<00:08,  2.33it/s]#015 75%|███████▍  | 53/71 [00:22<00:07,  2.34it/s]#015 76%|███████▌  | 54/71 [00:22<00:07,  2.34it/s]#015 77%|███████▋  | 55/71 [00:23<00:06,  2.34it/s]#015 79%|███████▉  | 56/71 [00:23<00:07,  2.06it/s]#015 80%|████████  | 57/71 [00:24<00:08,  1.63it/s]#015 82%|████████▏ | 58/71 [00:25<00:09,  1.43it/s]#015 83%|████████▎ | 59/71 [00:26<00:07,  1.62it/s]#015 85%|████████▍ | 60/71 [00:26<00:06,  1.77it/s]#015 86%|████████▌ | 61/71 [00:27<00:05,  1.91it/s]#015 87%|████████▋ | 62/71 [00:27<00:04,  2.02it/s]#015 89%|████████▊ | 63/71 [00:27<00:03,  2.10it/s]#015 90%|█████████ | 64/71 [00:28<00:03,  2.17it/s]#015 92%|█████████▏| 65/71 [00:28<00:02,  2.23it/s]#015 93%|█████████▎| 66/71 [00:29<00:02,  2.27it/s]#015 94%|█████████▍| 67/71 [00:29<00:01,  2.29it/s]#015 96%|█████████▌| 68/71 [00:30<00:01,  2.31it/s]#015 97%|█████████▋| 69/71 [00:30<00:00,  2.32it/s]#015 99%|█████████▊| 70/71 [00:30<00:00,  2.34it/s]#015100%|██████████| 71/71 [00:31<00:00,  2.53it/s]#015100%|██████████| 71/71 [00:31<00:00,  2.28it/s]
#
#
# 2021-07-16 21:14:53 Uploading - Uploading generated training model
# 2021-07-16 21:15:19 Completed - Training job completed

# %% [markdown]
# ## Accessing Training Metrics

# %%
# Captured metrics can be accessed as a Pandas dataframe
df = TrainingJobAnalytics(training_job_name=huggingface_estimator.latest_training_job.name).dataframe()
df.head(10)

# %% [markdown]
# # Deploying the endpoint

# %%
# create Hugging Face Model Class
huggingface_model = HuggingFaceModel(
   model_data=model_data, # S3 path to your trained sagemaker model
   role=role, # IAM role with permissions to create an Endpoint
    transformers_version='4.6',
    tensorflow_version='2.4',
    py_version='py37',
)

# %%
# deploy model to SageMaker Inference
predictor = huggingface_model.deploy(
    initial_instance_count=1,
    instance_type="ml.m5.xlarge"
)

# %% [markdown]
# ### invoke iwth the Python SDK

# %%
test['text'][:1].tolist()

# %%
# data = {"inputs": test['text'][:2].tolist()} 
# print(predictor.predict(data))

# %% [markdown]
# ### Alternative: invoke with boto3

# %%
# runtime = boto3.client("sagemaker-runtime")

# %% [markdown]
# ## DATA CITATION
